# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import plotly.express as px
import warnings 
warnings.filterwarnings('ignore')
from pyod.models.abod import ABOD
from pyod.models.knn import KNN

# %% [markdown]
# # Dataset

# %%
data = pd.read_csv('body.csv', dtype={'stop_name': 'str','daytime_routes': 'str','division':'str','line':'str','complex_id':'str'})

# %%
data
# Out:
#                      stop_name daytime_routes division     line borough  \
# 0       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# ...                        ...            ...      ...      ...     ...
# 159528              Journal Sq            NaN      PTH      NaN     NaN
# 159529              Journal Sq            NaN      PTH      NaN     NaN
# 159530              Journal Sq            NaN      PTH      NaN     NaN
# 159531              Journal Sq            NaN      PTH      NaN     NaN
# 159532              Journal Sq            NaN      PTH      NaN     NaN
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 159528       NaN      -74.068633      40.730304       R552  2020-12-21
# 159529       NaN      -74.068633      40.730304       R552  2020-12-22
# 159530       NaN      -74.068633      40.730304       R552  2020-12-23
# 159531       NaN      -74.068633      40.730304       R552  2020-12-24
# 159532       NaN      -74.068633      40.730304       R552  2020-12-25
#
#         entries    exits
# 0        5812.0   6659.0
# 1       15506.0  14307.0
# 2       15959.0  14500.0
# 3        9265.0   9161.0
# 4        7191.0   7743.0
# ...         ...      ...
# 159528   9116.0  10446.0
# 159529   9225.0  10445.0
# 159530   9361.0   8109.0
# 159531   7652.0   6975.0
# 159532   3022.0   2988.0
#
# [159533 rows x 12 columns]

# %% [markdown]
# # Data Cleansing

# %%
# Identifying Null Values in the dataset
data.isnull()
# Out:
#         stop_name  daytime_routes  division   line  borough  structure  \
# 0           False           False     False  False    False      False
# 1           False           False     False  False    False      False
# 2           False           False     False  False    False      False
# 3           False           False     False  False    False      False
# 4           False           False     False  False    False      False
# ...           ...             ...       ...    ...      ...        ...
# 159528      False            True     False   True     True       True
# 159529      False            True     False   True     True       True
# 159530      False            True     False   True     True       True
# 159531      False            True     False   True     True       True
# 159532      False            True     False   True     True       True
#
#         gtfs_longitude  gtfs_latitude  complex_id   date  entries  exits
# 0                False          False       False  False    False  False
# 1                False          False       False  False    False  False
# 2                False          False       False  False    False  False
# 3                False          False       False  False    False  False
# 4                False          False       False  False    False  False
# ...                ...            ...         ...    ...      ...    ...
# 159528           False          False       False  False    False  False
# 159529           False          False       False  False    False  False
# 159530           False          False       False  False    False  False
# 159531           False          False       False  False    False  False
# 159532           False          False       False  False    False  False
#
# [159533 rows x 12 columns]

# %%
#Total number of null values in each column.
data.isnull().sum()
# Out:
# stop_name          116
# daytime_routes    6236
# division           116
# line              6236
# borough           6236
# structure         6236
# gtfs_longitude     116
# gtfs_latitude      116
# complex_id           0
# date                 0
# entries             23
# exits               23
# dtype: int64

# %%
# Dropping null values from dataset,dropna() drop all rows with null values.
cd = data.dropna()
cd
# Out:
#                      stop_name daytime_routes division     line borough  \
# 0       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# ...                        ...            ...      ...      ...     ...
# 153292              Lorimer St            J M      BMT  Jamaica      Bk
# 153293              Lorimer St            J M      BMT  Jamaica      Bk
# 153294              Lorimer St            J M      BMT  Jamaica      Bk
# 153295              Lorimer St            J M      BMT  Jamaica      Bk
# 153296              Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits
# 0        5812.0   6659.0
# 1       15506.0  14307.0
# 2       15959.0  14500.0
# 3        9265.0   9161.0
# 4        7191.0   7743.0
# ...         ...      ...
# 153292   1771.0   1842.0
# 153293   1775.0   1783.0
# 153294   1767.0   1860.0
# 153295   1465.0   1545.0
# 153296    539.0    704.0
#
# [153277 rows x 12 columns]

# %%
#Modifying dateset by removing extra spaces and dashes.
cd.stop_name=cd.stop_name.str.replace('-','').fillna(cd.stop_name)

# %%
#A new dataframe, A cleaned dataframe 
cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits
# 0        5812.0   6659.0
# 1       15506.0  14307.0
# 2       15959.0  14500.0
# 3        9265.0   9161.0
# 4        7191.0   7743.0
# ...         ...      ...
# 153292   1771.0   1842.0
# 153293   1775.0   1783.0
# 153294   1767.0   1860.0
# 153295   1465.0   1545.0
# 153296    539.0    704.0
#
# [153277 rows x 12 columns]

# %%
#Identifying the outliers in dataset.
sns.set_palette(sns.color_palette("crest"))
plt.figure(figsize=(20,4))
x = cd['entries']
y = cd['exits']
sns.relplot(data=cd, x=x, y=y, kind="scatter", hue="borough",aspect=11.7/4.27, height=4)

# %% [markdown]
# # Angled Based Outlier Detection ABOD

# %%
abod_model = ABOD(contamination=0.3, method='fast', n_neighbors=10)
abod_model.fit(cd[['entries','exits']])
# Out:
# ABOD(contamination=0.3, method='fast', n_neighbors=10)

# %%
cd['entries_ABOD'] = abod_model.decision_function(cd[['entries','exits']])

# %%
cd['anomaly_ABOD'] = abod_model.predict(cd[['entries','exits']])
cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits  entries_ABOD  anomaly_ABOD
# 0        5812.0   6659.0 -6.212238e-08             0
# 1       15506.0  14307.0 -6.524665e-09             0
# 2       15959.0  14500.0 -3.804586e-10             0
# 3        9265.0   9161.0 -1.284716e-08             0
# 4        7191.0   7743.0 -2.564345e-07             0
# ...         ...      ...           ...           ...
# 153292   1771.0   1842.0 -2.997675e-04             0
# 153293   1775.0   1783.0 -3.207254e-03             0
# 153294   1767.0   1860.0 -1.304666e-03             0
# 153295   1465.0   1545.0 -3.981888e-04             0
# 153296    539.0    704.0 -1.640067e-03             0
#
# [153277 rows x 14 columns]

# %%
cd[cd['anomaly_ABOD']==0]
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits  entries_ABOD  anomaly_ABOD
# 0        5812.0   6659.0 -6.212238e-08             0
# 1       15506.0  14307.0 -6.524665e-09             0
# 2       15959.0  14500.0 -3.804586e-10             0
# 3        9265.0   9161.0 -1.284716e-08             0
# 4        7191.0   7743.0 -2.564345e-07             0
# ...         ...      ...           ...           ...
# 153292   1771.0   1842.0 -2.997675e-04             0
# 153293   1775.0   1783.0 -3.207254e-03             0
# 153294   1767.0   1860.0 -1.304666e-03             0
# 153295   1465.0   1545.0 -3.981888e-04             0
# 153296    539.0    704.0 -1.640067e-03             0
#
# [153277 rows x 14 columns]

# %%
total_outliers = len(cd[cd['anomaly_ABOD']!=0])

# %%
total_outliers
# Out:
# 0

# %%
total_inliers = len(cd[cd['anomaly_ABOD']==0])

# %%
total_inliers
# Out:
# 153277

# %%
sns.distplot(cd['anomaly_ABOD'])
# Out:
# <AxesSubplot:xlabel='anomaly_ABOD', ylabel='Density'>

# %% [markdown]
# # K-Nearest Neighbours KNN

# %%
from pyod.models.knn import KNN

# %%
knn_model = KNN(contamination = 0.3)

# %%
knn_model.fit(cd[['entries','exits']])
# Out:
# KNN(algorithm='auto', contamination=0.3, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
cd['entries_KNN'] = knn_model.decision_function(cd[['entries','exits']])

# %%
cd['anomaly_knn'] = knn_model.predict(cd[['entries','exits']])

# %%
cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits  entries_ABOD  anomaly_ABOD  entries_KNN  anomaly_knn
# 0        5812.0   6659.0 -6.212238e-08             0    60.406953            1
# 1       15506.0  14307.0 -6.524665e-09             0   198.297756            1
# 2       15959.0  14500.0 -3.804586e-10             0   191.783732            1
# 3        9265.0   9161.0 -1.284716e-08             0    96.607453            1
# 4        7191.0   7743.0 -2.564345e-07             0    44.553339            1
# ...         ...      ...           ...           ...          ...          ...
# 153292   1771.0   1842.0 -2.997675e-04             0     8.246211            0
# 153293   1775.0   1783.0 -3.207254e-03             0     6.082763            0
# 153294   1767.0   1860.0 -1.304666e-03             0     7.000000            0
# 153295   1465.0   1545.0 -3.981888e-04             0     8.246211            0
# 153296    539.0    704.0 -1.640067e-03             0     5.000000            0
#
# [153277 rows x 16 columns]

# %%
total_outliers_ = len(cd[cd['anomaly_knn']==1])

# %%
total_outliers_
# Out:
# 41818

# %%
total_inliers_ = len(cd[cd['anomaly_knn']==0])

# %%
total_inliers_
# Out:
# 111459

# %%
sns.distplot(cd['anomaly_knn'])
# Out:
# <AxesSubplot:xlabel='anomaly_knn', ylabel='Density'>

# %% [markdown]
# # Cluster-based Local Outlier Factor CBLOF

# %%
from pyod.models.cblof import CBLOF

# %%
cblof_model = CBLOF(contamination = 0.3)

# %%
cblof_model.fit(cd[['entries','exits']])
# Out:
# CBLOF(alpha=0.9, beta=5, check_estimator=False, clustering_estimator=None,
#    contamination=0.3, n_clusters=8, n_jobs=None, random_state=None,
#    use_weights=False)

# %%
cd['Score_CBLOF'] = cblof_model.decision_function(cd[['entries','exits']])

# %%
cd['Anomaly_CBLOF'] = cblof_model.predict(cd[['entries','exits']])

# %%
cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits  entries_ABOD  anomaly_ABOD  entries_KNN  \
# 0        5812.0   6659.0 -6.212238e-08             0    60.406953
# 1       15506.0  14307.0 -6.524665e-09             0   198.297756
# 2       15959.0  14500.0 -3.804586e-10             0   191.783732
# 3        9265.0   9161.0 -1.284716e-08             0    96.607453
# 4        7191.0   7743.0 -2.564345e-07             0    44.553339
# ...         ...      ...           ...           ...          ...
# 153292   1771.0   1842.0 -2.997675e-04             0     8.246211
# 153293   1775.0   1783.0 -3.207254e-03             0     6.082763
# 153294   1767.0   1860.0 -1.304666e-03             0     7.000000
# 153295   1465.0   1545.0 -3.981888e-04             0     8.246211
# 153296    539.0    704.0 -1.640067e-03             0     5.000000
#
#         anomaly_knn  Score_CBLOF  Anomaly_CBLOF
# 0                 1  3179.135383              1
# 1                 1  8322.798547              1
# 2                 1  8784.550656              1
# 3                 1   681.548773              0
# 4                 1  2454.740187              1
# ...             ...          ...            ...
# 153292            0   876.791809              0
# 153293            0   832.721629              0
# 153294            0   888.958205              0
# 153295            0   460.956856              0
# 153296            0   831.328365              0
#
# [153277 rows x 18 columns]

# %%
total_outliers_2 = len(cd[cd['Anomaly_CBLOF']==1])

# %%
total_outliers_2
# Out:
# 45983

# %%
total_inliers_2 = len(cd[cd['Anomaly_CBLOF']==0])
total_inliers_2
# Out:
# 107294

# %%
sns.distplot(cd['Anomaly_CBLOF'])
# Out:
# <AxesSubplot:xlabel='Anomaly_CBLOF', ylabel='Density'>

# %% [markdown]
# # Isolation Forest IForest

# %%
from pyod.models.iforest import IForest

# %%
iforest_model = IForest(contamination = 0.3)

# %%
iforest_model.fit(cd[['entries','exits']])
# Out:
# IForest(behaviour='old', bootstrap=False, contamination=0.3, max_features=1.0,
#     max_samples='auto', n_estimators=100, n_jobs=1, random_state=None,
#     verbose=0)

# %%
cd['Score_iForest'] = iforest_model.decision_function(cd[['entries','exits']])

# %%
cd['Anomaly_iforest'] = iforest_model.predict(cd[['entries','exits']])

# %%
cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# 0       Elevated      -73.912034      40.775036          1  2020-01-01
# 1       Elevated      -73.912034      40.775036          1  2020-01-02
# 2       Elevated      -73.912034      40.775036          1  2020-01-03
# 3       Elevated      -73.912034      40.775036          1  2020-01-04
# 4       Elevated      -73.912034      40.775036          1  2020-01-05
# ...          ...             ...            ...        ...         ...
# 153292  Elevated      -73.947408      40.703869         99  2020-12-21
# 153293  Elevated      -73.947408      40.703869         99  2020-12-22
# 153294  Elevated      -73.947408      40.703869         99  2020-12-23
# 153295  Elevated      -73.947408      40.703869         99  2020-12-24
# 153296  Elevated      -73.947408      40.703869         99  2020-12-25
#
#         entries    exits  entries_ABOD  anomaly_ABOD  entries_KNN  \
# 0        5812.0   6659.0 -6.212238e-08             0    60.406953
# 1       15506.0  14307.0 -6.524665e-09             0   198.297756
# 2       15959.0  14500.0 -3.804586e-10             0   191.783732
# 3        9265.0   9161.0 -1.284716e-08             0    96.607453
# 4        7191.0   7743.0 -2.564345e-07             0    44.553339
# ...         ...      ...           ...           ...          ...
# 153292   1771.0   1842.0 -2.997675e-04             0     8.246211
# 153293   1775.0   1783.0 -3.207254e-03             0     6.082763
# 153294   1767.0   1860.0 -1.304666e-03             0     7.000000
# 153295   1465.0   1545.0 -3.981888e-04             0     8.246211
# 153296    539.0    704.0 -1.640067e-03             0     5.000000
#
#         anomaly_knn  Score_CBLOF  Anomaly_CBLOF  Score_iForest  \
# 0                 1  3179.135383              1       0.034648
# 1                 1  8322.798547              1       0.162832
# 2                 1  8784.550656              1       0.167732
# 3                 1   681.548773              0       0.083595
# 4                 1  2454.740187              1       0.051792
# ...             ...          ...            ...            ...
# 153292            0   876.791809              0      -0.055063
# 153293            0   832.721629              0      -0.056718
# 153294            0   888.958205              0      -0.053839
# 153295            0   460.956856              0      -0.069326
# 153296            0   831.328365              0      -0.054086
#
#         Anomaly_iforest
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 153292                0
# 153293                0
# 153294                0
# 153295                0
# 153296                0
#
# [153277 rows x 20 columns]

# %%
total_outliers_iforest = len(cd[cd['Anomaly_iforest']==1])

# %%
total_outliers_iforest
# Out:
# 45983

# %%
total_inliers_iforest = len(cd[cd['Anomaly_iforest']==0])

# %%
total_inliers_iforest
# Out:
# 107294

# %%
sns.distplot(cd['Anomaly_iforest'])
# Out:
# <AxesSubplot:xlabel='Anomaly_iforest', ylabel='Density'>
