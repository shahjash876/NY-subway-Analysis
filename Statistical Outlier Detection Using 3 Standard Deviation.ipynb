# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import plotly.express as px
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('body.csv', dtype={'stop_name': 'str','daytime_routes': 'str','division':'str','line':'str','complex_id':'str'})

# %%
data
# Out:
#                      stop_name daytime_routes division     line borough  \
# 0       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria - Ditmars Blvd            N W      BMT  Astoria       Q
# ...                        ...            ...      ...      ...     ...
# 159528              Journal Sq            NaN      PTH      NaN     NaN
# 159529              Journal Sq            NaN      PTH      NaN     NaN
# 159530              Journal Sq            NaN      PTH      NaN     NaN
# 159531              Journal Sq            NaN      PTH      NaN     NaN
# 159532              Journal Sq            NaN      PTH      NaN     NaN
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# ...

# %%
data.isnull()
# Out:
#         stop_name  daytime_routes  division   line  borough  structure  \
# 0           False           False     False  False    False      False
# 1           False           False     False  False    False      False
# 2           False           False     False  False    False      False
# 3           False           False     False  False    False      False
# 4           False           False     False  False    False      False
# ...           ...             ...       ...    ...      ...        ...
# 159528      False            True     False   True     True       True
# 159529      False            True     False   True     True       True
# 159530      False            True     False   True     True       True
# 159531      False            True     False   True     True       True
# 159532      False            True     False   True     True       True
#
#         gtfs_longitude  gtfs_latitude  complex_id   date  entries  exits
# ...

# %%
data.isnull().sum()
# Out:
# stop_name          116
# daytime_routes    6236
# division           116
# line              6236
# borough           6236
# structure         6236
# gtfs_longitude     116
# gtfs_latitude      116
# complex_id           0
# date                 0
# entries             23
# exits               23
# dtype: int64

# %%
cd = data.dropna()

# %%
cd.stop_name=cd.stop_name.str.replace('-','').fillna(cd.stop_name)

# %%
cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# ...

# %%
cd.describe()
# Out:
#        gtfs_longitude  gtfs_latitude        entries          exits
# count   153277.000000  153277.000000  153277.000000  153277.000000
# mean       -73.933276      40.729674    4034.546494    3700.433111
# std          0.057345       0.080119    8155.785614    7727.061295
# min        -74.074835      40.576127       0.000000       0.000000
# 25%        -73.980305      40.674772     935.000000     808.000000
# 50%        -73.944890      40.718331    1923.000000    1759.000000
# 75%        -73.897174      40.791642    4051.000000    3682.000000
# max        -73.755405      40.903125  197283.000000  186847.000000

# %% [markdown]
# # Detecting Outliers Using 3 Standard Deviation

# %%
#Since the data is large we use 3 SD
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(cd['entries'])
plt.subplot(1,2,2)
sns.distplot(cd['exits'])
plt.show()

# %%
upper = cd['entries'].mean() + 3*cd['entries'].std()
lower = cd['entries'].mean() - 3*cd['entries'].std()

# %%
upper
# Out:
# 28501.903337257412

# %%
lower
# Out:
# -20432.810348746418

# %%
#finding outliers
cd[(cd['entries'] < 28501.90) | (cd['entries'] > -20432.81)]
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# ...

# %%
#removing outliers from data
new_cd = cd[(cd['entries'] < 28501.90) & (cd['entries'] > -20432.81)]
new_cd
# Out:
#                     stop_name daytime_routes division     line borough  \
# 0       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 1       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 2       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 3       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# 4       Astoria  Ditmars Blvd            N W      BMT  Astoria       Q
# ...                       ...            ...      ...      ...     ...
# 153292             Lorimer St            J M      BMT  Jamaica      Bk
# 153293             Lorimer St            J M      BMT  Jamaica      Bk
# 153294             Lorimer St            J M      BMT  Jamaica      Bk
# 153295             Lorimer St            J M      BMT  Jamaica      Bk
# 153296             Lorimer St            J M      BMT  Jamaica      Bk
#
#        structure  gtfs_longitude  gtfs_latitude complex_id        date  \
# ...

# %%
#Capping
upper_limit = cd['entries'].mean() + 3*cd['entries'].std()
lower_limit = cd['entries'].mean() - 3*cd['entries'].std()

# %%
upper_limit
# Out:
# 28501.903337257412

# %%
lower_limit
# Out:
# -20432.810348746418

# %%
cd['entries'] = np.where(
    cd['entries']>upper_limit,
    upper_limit,
    np.where(
        cd['entries']<lower_limit,
        lower_limit,
        cd['entries']
    )
)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_cd['entries'])
plt.subplot(2,2,2)
sns.boxplot(new_cd['entries'])
plt.subplot(2,2,3)
sns.distplot(cd['entries'])
plt.subplot(2,2,4)
sns.boxplot(cd['entries'])
plt.show()
